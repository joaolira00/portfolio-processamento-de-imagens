# %% [markdown]
# <a href="https://colab.research.google.com/github/joaolira00/libs_processamentos_imagens/blob/main/ProcessamentoDeImagensLibs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files # upload pros arquivos
import cv2 # lib do openCV
from google.colab.patches import cv2_imshow # imshow() para oooo

# %%
arquivo = files.upload()
# Out:
#      <input type="file" id="files-6fff3a6b-9f00-485f-9d47-45b761a6abba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6fff3a6b-9f00-485f-9d47-45b761a6abba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = cv2.imread('eles_estao_de_olho_em_nois_da_silva.jpg')
img
# Out:
# array([[[ 36,  14,   2],
#         [ 36,  14,   2],
#         [ 36,  14,   2],
#         ...,
#         [197,  73,   3],
#         [197,  73,   3],
#         [197,  73,   3]],
#
#        [[ 36,  14,   2],
#         [ 36,  14,   2],
#         [ 36,  14,   2],
#         ...,
#         [197,  73,   3],
#         [197,  73,   3],
#         [197,  73,   3]],
#
#        [[ 36,  14,   2],
#         [ 36,  14,   2],
#         [ 36,  14,   2],
#         ...,
#         [197,  73,   3],
#         [197,  73,   3],
#         [197,  73,   3]],
#
#        ...,
#
#        [[ 36,  23,  15],
#         [ 33,  20,  12],
#         [ 30,  17,   9],
#         ...,
#         [ 22,  13,   9],
#         [ 22,  13,   9],
#         [ 22,  13,   9]],
#
#        [[ 34,  21,  13],
#         [ 35,  22,  14],
#         [ 35,  22,  14],
#         ...,
#         [ 22,  13,   9],
#         [ 22,  13,   9],
#         [ 22,  13,   9]],
#
#        [[ 33,  20,  12],
#         [ 35,  22,  14],
#         [ 38,  25,  17],
# ...

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=550x556>

# %%
cv2_imshow(img/8)
# Out:
# <PIL.Image.Image image mode=RGB size=550x556>

# %%
cv2_imshow(img*100)
# Out:
# <PIL.Image.Image image mode=RGB size=550x556>

# %%
B, G, R = cv2.split(img)

# %%
cv2_imshow(B)
cv2_imshow(G)
cv2_imshow(R)
# Out:
# <PIL.Image.Image image mode=L size=550x556>
# <PIL.Image.Image image mode=L size=550x556>
# <PIL.Image.Image image mode=L size=550x556>

# %%
cv2_imshow(255-img)
# Out:
# <PIL.Image.Image image mode=RGB size=550x556>
